# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import matplotlib.pyplot as plt
import numpy as np

import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

from autoencoder import ConvAutoencoder
from solver import dev_train_vali_all_epochs_conv, test_conv
from rf_computation import compute_rf_for_single_model

# %%
print(torch.cuda.is_available())
device = torch.device(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
# Out:
# False

# %%
save_path = '/home/david/paper_cifar_models/cnn/singular_step_5_init/'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
# CIFAR10 normalization (RGB channels)
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))
])

# Load CIFAR10 datasets
cifar_train = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
cifar_test = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# Split training set into train/validation
train_size = int(len(cifar_train) * 0.8)  # 40,000 samples
validation_size = len(cifar_train) - train_size  # 10,000 samples
cifar_train, cifar_val = torch.utils.data.random_split(cifar_train, [train_size, validation_size])

# Create data loaders
batch_size = 128
train_loader = DataLoader(cifar_train, batch_size=batch_size, shuffle=True, num_workers=6)
validation_loader = DataLoader(cifar_val, batch_size=batch_size, shuffle=False, num_workers=6)
test_loader = DataLoader(cifar_test, batch_size=batch_size, shuffle=False, num_workers=6)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dae_model = ConvAutoencoder(latent_dim=64)
dae_optimizer = torch.optim.SGD(dae_model.parameters(), lr=0.1, momentum=0.9)
print(dae_model)
# Out:
# ConvAutoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): ReLU(inplace=True)
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Flatten(start_dim=1, end_dim=-1)
#     (11): Linear(in_features=1024, out_features=64, bias=True)
#   )
#   (linear): Sequential(
#     (0): Linear(in_features=64, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (5): ReLU(inplace=True)
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): ConvTranspose2d(32, 3, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (9): Tanh()
#   )
# )

# %%
size_ls = (
	[5] * 10 + [6] * 5 + [7] * 5 + [8] * 5 + [9] * 5
	+ [10] * 5 + [11] * 5 + [12] * 5 + [13] * 5 + [14] * 5 + [15] * 5 + [16] * 5 
    + [17] * 4 + [18] * 4 + [19] * 4
	+ [20] * 4 + [21] * 4 + [22] * 4 + [23] * 4 + [24] * 4 + [25] * 4 + [26] * 4 + [27] * 4 + [28] * 4 + [29] * 4 
    + [30] * 4 + [31] * 4 + [32] * 4 + [33] * 3 + [34] * 3 + [35] * 3 + [36] * 3
	+ [37] * 3 + [38] * 3 + [39] * 3 + [40] * 3 + [41] * 3 + [42] * 3 + [43] * 3 + [44] * 3 + [45] * 3 + [46] * 3 
    + [47] * 3 + [48] * 3 + [49] * 2 + [50] * 2
	+ [51] * 2 + [52] * 2 + [53] * 2 + [54] * 2 + [55] * 2 + [56] * 2 + [57] * 2 + [58] * 2 + [59] * 2 + [60] * 2 
    + [61] * 2 + [62] * 2 + [63] * 2 + [64] * 2
	# + [65] * 5 + [66] * 5 + [67] * 5 + [68] * 5 + [69] * 5 + [70] * 5 + [71] * 5 + [72] * 5 + [73] * 5 + [74] * 5 
    # + [75] * 5 + [76] * 5 + [77] * 5 + [78] * 5 + [79] * 5
	# + [80] * 5 + [81] * 5 + [82] * 5 + [83] * 5 + [84] * 5 + [85] * 5 + [86] * 5 + [87] * 5 + [88] * 5 + [89] * 5 
    # + [90] * 5 + [91] * 5 + [92] * 5 + [93] * 5
	# + [94] * 5 + [95] * 5 + [96] * 5 + [97] * 5 + [98] * 5 + [99] * 5 + [100] * 5 + [101] * 5 + [102] * 5 
    # + [103] * 5 + [104] * 5 + [105] * 5 + [106] * 5
	# + [107] * 5 + [108] * 5 + [109] * 5 + [110] * 5 + [111] * 5 + [112] * 5 + [113] * 5 + [114] * 5 + [115] * 5 
    # + [116] * 5 + [117] * 5 + [118] * 5 + [119] * 5
	# + [120] * 5 + [121] * 5 + [122] * 5 + [123] * 5 + [124] * 5 + [125] * 5 + [126] * 5 + [127] * 5 + [128] * 5
)

# %%
# train_loss,vali_loss = dev_train_vali_all_epochs_conv(
#                                                             dae_model,
#                                                             size_ls,
#                                                             train_loader,
#                                                             validation_loader,
#                                                             dae_optimizer,
#                                                             len(size_ls),
#                                                             device,
#                                                             save_path
#                                                             )

# %%
all_train_loss = np.load(f"{save_path}/all_train_losses.npy")
plt.plot(all_train_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss over Epochs')
plt.gcf().set_size_inches(25, 10)
plt.show()

# %%
import tqdm
from model_utils import load_conv_model
import act_max_util as amu

IMG_WIDTH, IMG_HEIGHT = 32, 32
MAX_NEURONS = 64

steps = 100               # perform 100 iterations
alpha = torch.tensor(100) # learning rate (step size)
verbose = False           # print activation every step
L2_Decay = True           # enable L2 decay regularizer
Gaussian_Blur = False     # enable Gaussian regularizer
Norm_Crop = False         # enable norm regularizer
Contrib_Crop = False      # enable contribution regularizer

model_type = "dae"

rf_matrix = []

for epoch in range(1):
    data = torch.randn(3, IMG_WIDTH, IMG_HEIGHT)
    input = data.unsqueeze(0)
    
    input.requires_grad_(True)

    model_path = f"/home/david/paper_cifar_models/cnn/singular_step_5_init"
    ae = load_conv_model(model_path, model_type="dae", epoch=208, size_ls=size_ls)
    
    layer_name = 'bottle_neck'
    activation_dictionary = {}

    ae.encoder[11].register_forward_hook(amu.layer_hook(activation_dictionary, layer_name))

    loop_size = size_ls[epoch] if model_type == "dae" else MAX_NEURONS

    rf_ls = []
    for i in range(loop_size):
        output = amu.act_max(network=ae,
                        input=input,
                        layer_activation=activation_dictionary,
                        layer_name=layer_name,
                        unit=i,
                        steps=steps,
                        alpha=alpha,
                        verbose=verbose,
                        L2_Decay=L2_Decay,
                        Gaussian_Blur=Gaussian_Blur,
                        Norm_Crop=Norm_Crop,
                        Contrib_Crop=Contrib_Crop,
                        )
        rf_ls.append(output.detach().numpy())
    
    max_size = MAX_NEURONS

    # Pad the rf_ls list to max_size before converting to numpy array
    if loop_size < max_size:
        zero_rf = np.zeros_like(rf_ls[0])
        for _ in range(loop_size, max_size):
            rf_ls.append(zero_rf.copy())
    
    rf_ls = np.array(rf_ls).squeeze()
    rf_matrix.append(rf_ls)
# Out:
# 64
# /home/david/paper_cifar_models/cnn/singular_step_5_init/model_weights_epoch208.pth

# %%
np.array(rf_matrix).squeeze()[0].shape


plt.imshow(np.transpose(np.array(rf_matrix).squeeze()[20], (1, 2, 0)), cmap='gray')

# %%
# 64
test_iter = iter(test_loader)
test_images, test_labels = next(test_iter)
test_image = test_images[0].unsqueeze(0)

plt.imshow(test_image.squeeze().permute(1, 2, 0).numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7830755..2.0942786].

# %%
reconstructed_image = ae(test_image)[1].detach().squeeze().permute(1, 2, 0).numpy()
plt.imshow(reconstructed_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9978125..0.9999906].

# %%
# get reconstruction of first image

reconstructed_image = ae(test_image)[1].detach().squeeze().permute(1, 2, 0).numpy()
plt.imshow(reconstructed_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9978125..0.9999906].

# %%
test_loss, decoded,test = test_conv(ae,test_loader)
fig = plt.figure(figsize=(20,10))
for i in range(10):
    plt.subplot(3,10,i+1)
    plt.imshow(np.transpose(test[i].numpy(),(1,2,0)))
    if i == 0:
        plt.title('Original')
    plt.axis('off')

    plt.subplot(3,10,i+11)
    plt.imshow(np.transpose(decoded[i].detach().numpy(),(1,2,0)))
    if i == 0:
        plt.title('SAE Reconstructed')
    plt.axis('off')
# Out:
# ====> Test set loss: 689.8991
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.6401843..1.9320949].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.99926496..0.99999386].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9894737..1.9654387].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9894737..2.115826].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9996373..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9641825..1.8844646].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.97742987..0.9999999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9894737..2.1264887].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9999999..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5131699..1.7415735].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9999928..0.9999669].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8624594..2.1264887].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9894737..2.1264887].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9964206..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9802876..2.1264887].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8031324..2.115826].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9999943..1.0].

# %%
import tqdm
from model_utils import load_conv_model
import act_max_util as amu

model_path = f"/home/david/paper_cifar_models/cnn/singular_step_5_init"
ae = load_conv_model(model_path, model_type="dae", epoch=208, size_ls=size_ls)

IMG_WIDTH, IMG_HEIGHT = 32, 32
MAX_NEURONS = 64

steps = 100               # perform 100 iterations
alpha = torch.tensor(100) # learning rate (step size)
verbose = False           # print activation every step
L2_Decay = True           # enable L2 decay regularizer
Gaussian_Blur = False     # enable Gaussian regularizer
Norm_Crop = False         # enable norm regularizer
Contrib_Crop = False      # enable contribution regularizer


activation_dictionary = {}
layer_name = 'bottle_neck'
ae.encoder[11].register_forward_hook(amu.layer_hook(activation_dictionary, layer_name))

data = torch.randn(3,32, 32)
input = data.unsqueeze(0)
# input = data.view(data.size(0), -1)
input.requires_grad_(True)
print(input.shape)

dae_rf_ls = []
for i in range(64):
    output = amu.act_max(network=ae,
                    input=input,
                    layer_activation=activation_dictionary,
                    layer_name=layer_name,
                    unit=i,
                    steps=steps,
                    alpha=alpha,
                    verbose=verbose,
                    L2_Decay=L2_Decay,
                    Gaussian_Blur=Gaussian_Blur,
                    Norm_Crop=Norm_Crop,
                    Contrib_Crop=Contrib_Crop,
                    )
    dae_rf_ls.append(output.detach().numpy())

fig = plt.figure(figsize=(30,30))
for i in range(64):
    plt.subplot(16,16,i+1)
    if i == 0:
        plt.title('dae')
    else:
        plt.title(str(i+1))
    plt.axis('off')
    plt.xticks([])
    plt.yticks([])
    plt.imshow(np.transpose(dae_rf_ls[i].reshape(3,32,32), (1,2,0)))
plt.show()
# Out:
# 64
# /home/david/paper_cifar_models/cnn/singular_step_5_init/model_weights_epoch208.pth
# torch.Size([1, 3, 32, 32])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-78.3472..58.70554].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-139.35643..122.220505].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-79.79466..56.945885].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-173.12349..122.295685].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-9.362302..11.252092].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-72.241646..52.814064].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-45.869835..40.060555].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-64.32391..59.39423].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-34.978935..39.489876].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-44.484158..38.237362].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-58.57739..48.51699].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-65.091415..46.162064].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-44.851875..45.678513].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-46.58096..66.11005].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-69.3321..52.471447].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-47.51504..42.755573].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-57.07643..47.817444].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-50.740738..52.503643].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-32.964058..33.183914].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-66.36777..44.21234].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-44.220177..48.46976].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-41.464207..65.01733].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-37.49579..35.793564].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-49.44895..50.43739].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-51.795143..40.26841].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-48.727535..51.612534].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-58.3667..65.00562].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-68.46978..82.4544].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-46.500065..43.90391].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-42.200447..52.05907].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-52.136036..48.02722].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-53.842117..55.425335].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-41.41142..52.400497].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-61.39144..52.85633].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-46.453075..54.036667].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-44.09717..36.916718].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-45.55125..47.915634].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-52.987457..39.879196].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-74.81979..45.94585].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-67.923386..46.802055].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-49.022156..53.85639].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-46.434555..45.93525].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-48.529514..40.09815].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-53.979107..72.04814].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-51.049755..50.150894].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-75.89492..74.22495].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-38.40383..41.082382].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-65.3251..46.468975].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-36.61389..50.602654].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-46.010876..61.41211].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-60.13083..38.66125].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-57.155384..59.52956].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-68.47101..63.949505].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-63.415287..55.888683].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-45.78732..48.55937].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-66.12286..65.640816].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-53.98071..66.47227].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-44.18681..45.038704].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-79.91171..60.614906].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-46.12219..45.693405].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-40.299713..39.424908].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-55.9486..52.162075].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-53.941467..38.916294].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-41.94282..38.19587].
