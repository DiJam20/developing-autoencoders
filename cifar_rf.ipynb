# %%
import numpy as np
import matplotlib.pyplot as plt
import os, sys
from tqdm import tqdm
import argparse

import torch
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable
from torchvision.utils import save_image


from autoencoder import Autoencoder
from solver import *
from receptive_field import get_RF_linear

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/kong/anaconda3/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/kong/anaconda3/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZNK3c107SymBool10guard_boolEPKcl'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 15
#      11 from torch.autograd import Variable
#      12 from torchvision.utils import save_image
# ---> 15 from autoencoder import Autoencoder
#      16 from solver import *
#      17 from receptive_field import get_RF_linear
#
# ImportError: cannot import name 'Autoencoder' from 'autoencoder' (/home/kong/developing-autoencoders/autoencoder.py)

# %%
modelpath = os.getenv("HOME") + 'sparsify_models/good_models/01/'
plotpath = os.getenv("HOME") + 'sparsify_plots/RF/'
if not os.path.exists(plotpath):
    os.makedirs(plotpath)
